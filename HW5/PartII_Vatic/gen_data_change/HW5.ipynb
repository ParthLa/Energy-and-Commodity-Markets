# %% [markdown]
# # Part II (Vatic)

# %%
from vatic.engines import Simulator
from vatic.data.loaders import load_input, RtsLoader
from vatic.engines import Simulator

import pandas as pd
import numpy as np

from pathlib import Path
import dill as pickle
import os
from datetime import datetime
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
grid_name = "Texas-7k"
RUC_MIPGAPS = {grid_name: 0.01}
SCED_HORIZONS = {grid_name: 4}
grid = grid_name  #For Texas, put 'Texas-7k' or 'Texas-7k_2030'
num_days = 1  
init_state_file = None 

def get_input_for_simulation(date):
    start_date = date #For Texas pick a date in 2018
    template, gen_data, load_data = load_input(grid, start_date, num_days=num_days, init_state_file=init_state_file)
    return template, gen_data, load_data, start_date

# %%
CO2_data = pd.read_csv("emissions_CO2.csv")
dates = ["2018-01-19", "2018-07-19"]
scenario_index_to_name = {1: "baseline", 2: "cloudy", 3: "wind_equivalent"}

# %% [markdown]
# ### Baseline Simulation

# %%
siml = Simulator(template, gen_data, load_data, None,
                pd.to_datetime(start_date).date(), 1, solver='gurobi',
                solver_options={}, run_lmps=False, mipgap=RUC_MIPGAPS[grid],
                load_shed_penalty = 1e4, reserve_shortfall_penalty = 1e3,
                reserve_factor=0.05, output_detail=3,
                prescient_sced_forecasts=True, ruc_prescience_hour=0,
                ruc_execution_hour=16, ruc_every_hours=24,
                ruc_horizon=48, sced_horizon=SCED_HORIZONS[grid],
                lmp_shortfall_costs=False,
                enforce_sced_shutdown_ramprate=False,
                no_startup_shutdown_curves=False,
                init_ruc_file=None, verbosity=0,
                output_max_decimals=4, create_plots=False,
                renew_costs=None, save_to_csv=False, 
                last_conditions_file=None,)
report_dfs = siml.simulate()
# Out:
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-packages/vatic/models/params.py:1022)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:126)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:127)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:130)
# Calculating PTDF Matrix Factorization
# WARNING: DEPRECATED: The quicksum(linear=...) argument is deprecated and
# ignored.  (deprecated in 6.6.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/uc_utils.py:100)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:63)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:66)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:58)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:54)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:198)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:199)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:239)
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored

# %%
import pickle
with open("report_dfs.pkl", "wb") as f:
    pickle.dump(report_dfs, f)

# %%
thermal_detail = report_dfs["thermal_detail"].reset_index()
thermal_detail_co2 = pd.merge(thermal_detail, co2_data, left_on = "Generator", right_on = "GEN UID", how = "inner")
# Dispatch assumed to be in MWh
thermal_detail_co2["CO2_Total"] = thermal_detail_co2["Dispatch"]*thermal_detail_co2["CO2 Emissions Lbs/MWh"]
thermal_detail_co2["CO2_Total"].sum()
# Out:
# np.float64(1063377974.6755733)

# %% [markdown]
# ### Matching solar loss with equivalent wind loss

# %%
def get_actual_energy_columns(df, etype):
    output = []
    for col in df.columns:
        if(etype in col[1] and col[0] == "actl"):
            output.append(col)
    return output

def get_p_value(df):
    solar_cols = get_actual_energy_columns(df, 'Solar')
    wind_cols = get_actual_energy_columns(df, 'Wind')
    solar_sum = sum(df[solar_cols].sum(axis=1))
    wind_sum = sum(df[wind_cols].sum(axis=1))
    print(solar_sum, wind_sum)
    p = (solar_sum * 0.75) / wind_sum
    return p
    
def change_generation_data(gen_data, scenario):
    if(scenario == 2): # cloudy day
        solar_cols = get_actual_energy_columns(gen_data, "Solar")
        gen_data[solar_cols] *= 0.25
    elif(scenario == 3): # wind equivalend
        wind_cols = get_actual_energy_columns(gen_data, "Wind")
        p = get_p_value(gen_data)
        print("p value", p)
        gen_data[wind_cols] *= (1-p)
    return gen_data

def convert_lbs_to_metric_tons(x):
    '''
    Converts a value in lbs to metric tons
    '''
    return x/2204.6223

# %%
for date in dates:
    template, gen_data, load_data, start_date = get_input_for_simulation(date)
    for scenario in [1, 2, 3]:
        gen_data_modified = change_generation_data(gen_data, scenario)
        scenario_name = scenario_index_to_name[scenario]
        print(date, scenario_name, "Started!")
        siml = Simulator(template, gen_data_modified, load_data, None,
                    pd.to_datetime(start_date).date(), 1, solver='gurobi',
                    solver_options={}, run_lmps=False, mipgap=RUC_MIPGAPS[grid],
                    load_shed_penalty = 1e4, reserve_shortfall_penalty = 1e3,
                    reserve_factor=0.05, output_detail=3,
                    prescient_sced_forecasts=True, ruc_prescience_hour=0,
                    ruc_execution_hour=16, ruc_every_hours=24,
                    ruc_horizon=48, sced_horizon=SCED_HORIZONS[grid],
                    lmp_shortfall_costs=False,
                    enforce_sced_shutdown_ramprate=False,
                    no_startup_shutdown_curves=False,
                    init_ruc_file=None, verbosity=0,
                    output_max_decimals=4, create_plots=False,
                    renew_costs=None, save_to_csv=False, 
                    last_conditions_file=None,)
        # Computation
        report_dfs = siml.simulate()
        with open(f"report_dfs_{date}_{scenario_name}.pkl", "wb") as f:
            pickle.dump(report_dfs, f)
        print(date, scenario_name, "Finished!")
        print("")
# Out:
# 31324.076762651617 505316.56833711837
# p value 0.04649176188562154
# 2018-01-19 wind_equivalent Started!
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-packages/vatic/models/params.py:1022)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:126)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:127)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:130)
# Calculating PTDF Matrix Factorization
# WARNING: DEPRECATED: The quicksum(linear=...) argument is deprecated and
# ignored.  (deprecated in 6.6.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/uc_utils.py:100)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:63)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:66)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:58)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:54)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:198)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:199)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:239)
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# 2018-01-19 wind_equivalent Finished!
#
# 50785.63020434008 391233.68739672063
# p value 0.09735670490622052
# 2018-07-19 wind_equivalent Started!
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Truncating shutdown_curve longer than scaled minimum down time 1 for generator 50304_AllOther_GEN2
# Truncating shutdown_curve longer than scaled minimum down time 1 for generator 50304_AllOther_GEN2
# Truncating shutdown_curve longer than scaled minimum down time 1 for generator 50304_AllOther_GEN2
# Truncating shutdown_curve longer than scaled minimum down time 1 for generator 50304_AllOther_GEN2
# 2018-07-19 wind_equivalent Finished!

# %%
# Computing CO2 Emissions
CO2_df = pd.DataFrame(columns = ["date", "scenario_name", "CO2 Emissions (in MT)"])
row = 0
for date in dates:
    for scenario in [1, 2, 3]:
        scenario_name = scenario_index_to_name[scenario]
        # Fetching the stored pickle files
        with open(f"report_dfs_{date}_{scenario_name}.pkl", "rb") as f:
            report_dfs = pickle.load(f)
        # Extracting thermal details
        thermal_detail = report_dfs["thermal_detail"].reset_index()
        thermal_detail_CO2 = pd.merge(thermal_detail, CO2_data, left_on = "Generator", right_on = "GEN UID", how = "inner")
        # Dispatch assumed to be in MWh
        thermal_detail_CO2["CO2_Total"] = thermal_detail_CO2["Dispatch"]*thermal_detail_CO2["CO2 Emissions Lbs/MWh"]
        CO2_total = thermal_detail_CO2["CO2_Total"].sum()
        CO2_total = convert_lbs_to_metric_tons(CO2_total)
        print(date, scenario_name, CO2_total)
        CO2_df.loc[row] = [date, scenario_name, CO2_total]
        row += 1
        print("")
# Out:
# 2018-01-19 baseline 482340.20615484717
#
# 2018-01-19 cloudy 486732.5932620959
#
# 2018-01-19 wind_equivalent 487034.04493126826
#
# 2018-07-19 baseline 677450.4814349589
#
# 2018-07-19 cloudy 684518.494041032
#
# 2018-07-19 wind_equivalent 686277.0734749862

# %%
# temp = CO2_df.set_index(["date", "scenario_name"])
CO2_df["base_emissions"] = 0
for date in dates:
    val = CO2_df[(CO2_df["date"] == date) & (CO2_df["scenario_name"] == "baseline")]["CO2 Emissions (in MT)"].iloc[0]
    CO2_df.loc[CO2_df["date"] == date, "base_emissions"] = val
CO2_df["pct_change"] = (CO2_df["CO2 Emissions (in MT)"] - CO2_df["base_emissions"])*100/CO2_df["base_emissions"]
CO2_df
# Out:
#          date    scenario_name  CO2 Emissions (in MT)  base_emissions  \
# 0  2018-01-19         baseline          482340.206155   482340.206155
# 1  2018-01-19           cloudy          486732.593262   482340.206155
# 2  2018-01-19  wind_equivalent          487034.044931   482340.206155
# 3  2018-07-19         baseline          677450.481435   677450.481435
# 4  2018-07-19           cloudy          684518.494041   677450.481435
# 5  2018-07-19  wind_equivalent          686277.073475   677450.481435
#
#    pct_change
# 0    0.000000
# 1    0.910641
# 2    0.973139
# 3    0.000000
# 4    1.043325
# 5    1.302913

# %% [markdown]
# #### As seen, CO2 emissions increase in both cases when the solar or the wind generation is curtailed. Further, the increase is more in case of wind curtailment (0.97% vs 0.91%, 1.30% vs 1.04%) as compared to solar curtailment, indicating that wind saves a lot of CO2 from being emitted while fulfilling the demand! (Note that generation was only changed on the actual columns.)

# %% [markdown]
# ### Summer Daytime Demand Shock

# %%
import datetime

# %%
def change_load_data(load_data):
    '''
    Increases the demand (through load_data) between 10:00 to 18:00 hours by 40%
    Args:
        load_data (pd.DataFrame): load data
    Returns:
        modified load data (pd.DataFrame)
    '''
    v = load_data.index
    # Filtering on the July date
    v2 = v[v.date == pd.to_datetime("2018-07-19").date()]
    # Filtering on the times to be updated
    v3 = v2[(v2.time >= datetime.time(10)) & (v2.time <= datetime.time(18))]
    load_data.loc[v3, "actl"] *= 1.4
    return load_data

# %%
date = "2018-07-19"
template, gen_data, load_data, start_date = get_input_for_simulation(date)
load_data_modified = change_load_data(load_data)
siml = Simulator(template, gen_data, load_data_modified, None,
            pd.to_datetime(start_date).date(), 1, solver='gurobi',
            solver_options={}, run_lmps=False, mipgap=RUC_MIPGAPS[grid],
            load_shed_penalty = 1e4, reserve_shortfall_penalty = 1e3,
            reserve_factor=0.05, output_detail=3,
            prescient_sced_forecasts=True, ruc_prescience_hour=0,
            ruc_execution_hour=16, ruc_every_hours=24,
            ruc_horizon=48, sced_horizon=SCED_HORIZONS[grid],
            lmp_shortfall_costs=False,
            enforce_sced_shutdown_ramprate=False,
            no_startup_shutdown_curves=False,
            init_ruc_file=None, verbosity=0,
            output_max_decimals=4, create_plots=False,
            renew_costs=None, save_to_csv=False, 
            last_conditions_file=None,)
report_dfs = siml.simulate()

# Storing output
with open(f"report_dfs_{date}_demand_shock.pkl", "wb") as f:
    pickle.dump(report_dfs, f)
# Out:
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-packages/vatic/models/params.py:1022)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:126)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:127)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:130)
# Calculating PTDF Matrix Factorization
# WARNING: DEPRECATED: The quicksum(linear=...) argument is deprecated and
# ignored.  (deprecated in 6.6.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/uc_utils.py:100)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:63)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:66)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:58)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/power_vars.py:54)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:198)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:199)
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-
# packages/egret/model_library/unit_commitment/startup_costs.py:239)
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# WARNING: DEPRECATED: Param 'Demand' declared with an implicit domain of 'Any'.
# The default domain for Param objects is 'Any'.  However, we will be changing
# that default to 'Reals' in the future.  If you really intend the domain of
# this Paramto be 'Any', you can suppress this warning by explicitly specifying
# 'within=Any' to the Param constructor. (deprecated in 5.6.9, will be removed
# in (or after) 6.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-packages/pyomo/core/base/indexed_component.py:718)
# WARNING: DEPRECATED: Param 'TotalDemand' declared with an implicit domain of
# 'Any'. The default domain for Param objects is 'Any'.  However, we will be
# changing that default to 'Reals' in the future.  If you really intend the
# domain of this Paramto be 'Any', you can suppress this warning by explicitly
# specifying 'within=Any' to the Param constructor.  (deprecated in 5.6.9, will
# be removed in (or after) 6.0) (called from /home/pl7830/.conda/envs/vatic-
# test/lib/python3.11/site-packages/pyomo/core/base/indexed_component.py:788)
# ERROR: Rule failed for Param 'ReserveRequirement' with index 4: ValueError:
# Invalid parameter value: ReserveRequirement[4] = 'nan', value type=<class
# 'float'>.
#             Value not in parameter domain NonNegativeReals
# ERROR: Constructing component 'ReserveRequirement' from data=None failed:
#         ValueError: Invalid parameter value: ReserveRequirement[4] = 'nan',
#         value type=<class 'float'>.
#     	Value not in parameter domain NonNegativeReals
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 19
#       3 load_data_modified = change_load_data(load_data)
#       4 siml = Simulator(template, gen_data, load_data_modified, None,
#       5             pd.to_datetime(start_date).date(), 1, solver='gurobi',
#       6             solver_options={}, run_lmps=False, mipgap=RUC_MIPGAPS[grid],
#    (...)     17             renew_costs=None, save_to_csv=False,
#      18             last_conditions_file=None,)
# ---> 19 report_dfs = siml.simulate()
#      21 # Storing output
#      22 with open(f"report_dfs_{date}_demand_shock.pkl", "wb") as f:
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/vatic/engines.py:251, in Simulator.simulate(self)
#     249     # run the SCED to simulate this time step
#     250     oracle_start_time = time.time()
# --> 251     self.call_oracle()
#     252     self.simulation_times['Sim'] += time.time() - oracle_start_time
#     254 sim_time = time.time() - simulation_start_time
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/vatic/engines.py:327, in Simulator.call_oracle(self)
#     324 if self.verbosity > 0:
#     325     print("\nSolving SCED instance")
# --> 327 current_sced_instance = self.solve_sced(hours_in_objective=1,
#     328                                         sced_horizon=self.sced_horizon)
#     330 if self.verbosity > 0:
#     331     print("Solving for LMPs")
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/vatic/engines.py:461, in Simulator.solve_sced(self, hours_in_objective, sced_horizon)
#     458 else:
#     459     ptdf_options = self._ptdf_manager.sced_ptdf_options
# --> 461 self.sced_model.generate_model(
#     462     sced_model_data, relax_binaries=False, ptdf_options=ptdf_options,
#     463     ptdf_matrix_dict=self._ptdf_manager.PTDF_matrix_dict,
#     464     objective_hours=hours_in_objective
#     465     )
#     467 # update in case lines were taken out
#     468 self._ptdf_manager.PTDF_matrix_dict = self.sced_model.pyo_instance._PTDFs
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/vatic/models/_interface.py:141, in UCModel.generate_model(self, model_data, relax_binaries, ptdf_options, ptdf_matrix_dict, objective_hours)
#     138 model.enforce_t1_ramp_rates = True
#     139 model.relax_binaries = relax_binaries
# --> 141 self._load_params(model)
#     142 self._get_formulation('status_vars')(model)
#     143 self._get_formulation('power_vars')(model)
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/vatic/models/_interface.py:71, in UCModel._load_params(self, model)
#      68     renew_cost_params(model, VaticModelData(model.model_data.data))
#      70 elif self.params == 'default_params':
# ---> 71     default_params(model, VaticModelData(model.model_data.data))
#      73 else:
#      74     raise ModelError(
#      75         "Unrecognized model formulation `{}`!".format(self.params))
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/egret/model_library/unit_commitment/uc_utils.py:50, in add_model_attr.<locals>.actual_decorator.<locals>.wrapper(*args, **kwds)
#      48         warnings.warn(msg)
#      49 setattr(model, attr, func.__name__)
# ---> 50 return func(*args, **kwds)
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/vatic/models/params.py:1856, in default_params(model, model_data)
#    1850 @add_model_attr(component_name)
#    1851 def default_params(
#    1852         model: pe.ConcreteModel,
#    1853         model_data: Optional[VaticModelData] = None
#    1854         ) -> pe.ConcreteModel:
#    1855     """This loads unit commitment params from a GridModel object."""
# -> 1856     return load_base_params(model, model_data, renew_costs=False)
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/vatic/models/params.py:439, in load_base_params(model, model_data, renew_costs)
#     432 ##################################################################
#     433 # the global system reserve, for each time period. units are MW. #
#     434 ##################################################################
#     436 reserve_req = TimeMapper(
#     437     model_data.get_system_attr('reserve_requirement', 0.))
# --> 439 model.ReserveRequirement = pe.Param(model.TimePeriods,
#     440                                     within=pe.NonNegativeReals,
#     441                                     initialize=reserve_req, mutable=True)
#     443 ##########################################################################################################
#     444 # the minimum number of time periods that a generator must be on-line (off-line) once brought up (down). #
#     445 ##########################################################################################################
#     447 model.MinimumUpTime = pe.Param(
#     448     model.ThermalGenerators,
#     449     within=pe.NonNegativeReals, default=0,
#     450     initialize=thermal_gen_attrs['min_up_time']
#     451     )
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/pyomo/core/base/block.py:573, in BlockData.__setattr__(self, name, val)
#     568 if name not in self.__dict__:
#     569     if isinstance(val, Component):
#     570         #
#     571         # Pyomo components are added with the add_component method.
#     572         #
# --> 573         self.add_component(name, val)
#     574     else:
#     575         #
#     576         # Other Python objects are added with the standard __setattr__
#     577         # method.
#     578         #
#     579         super(BlockData, self).__setattr__(name, val)
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/pyomo/core/base/block.py:1103, in BlockData.add_component(self, name, val)
#    1095     logger.debug(
#    1096         "Constructing %s '%s' on %s from data=%s",
#    1097         val.__class__.__name__,
#    (...)   1100         str(data),
#    1101     )
#    1102 try:
# -> 1103     val.construct(data)
#    1104 except:
#    1105     err = sys.exc_info()[1]
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/pyomo/core/base/param.py:869, in Param.construct(self, data)
#     865 self._constructed = None
#     866 #
#     867 # Step #1: initialize data from rule value
#     868 #
# --> 869 self._construct_from_rule_using_setitem()
#     870 #
#     871 # Step #2: allow any user-specified (external) data to override
#     872 # the initialization
#     873 #
#     874 if data is not None:
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/pyomo/core/base/indexed_component.py:772, in IndexedComponent._construct_from_rule_using_setitem(self)
#     769 if rule.contains_indices():
#     770     # The index is coming in externally; we need to validate it
#     771     for index in rule.indices():
# --> 772         self[index] = rule(block, index)
#     773 elif not self.index_set().isfinite():
#     774     # If the index is not finite, then we cannot iterate
#     775     # over it.  Since the rule doesn't provide explicit
#     776     # indices, then there is nothing we can do (the
#     777     # assumption is that the user will trigger specific
#     778     # indices to be created at a later time).
#     779     pass
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/pyomo/core/base/indexed_component.py:718, in IndexedComponent.__setitem__(self, index, val)
#     716 obj = self._data.get(index, _NotFound)
#     717 if obj is _NotFound:
# --> 718     return self._setitem_when_not_present(index, val)
#     719 else:
#     720     return self._setitem_impl(index, obj, val)
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/pyomo/core/base/param.py:771, in Param._setitem_when_not_present(self, index, value, _check_domain)
#     769 elif self._mutable:
#     770     obj = self._data[index] = ParamData(self)
# --> 771     obj.set_value(value, index)
#     772     obj._index = index
#     773     return obj
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/pyomo/core/base/param.py:204, in ParamData.set_value(self, value, idx)
#     202 old_value, self._value = self._value, value
#     203 try:
# --> 204     _comp._validate_value(idx, value, data=self)
#     205 except:
#     206     self._value = old_value
#
# File ~/.conda/envs/vatic-test/lib/python3.11/site-packages/pyomo/core/base/param.py:794, in Param._validate_value(self, index, value, validate_domain, data)
#     792     if index is NOTSET:
#     793         index = data.index()
# --> 794     raise ValueError(
#     795         "Invalid parameter value: %s[%s] = '%s', value type=%s.\n"
#     796         "\tValue not in parameter domain %s"
#     797         % (self.name, index, value, type(value), self.domain.name)
#     798     )
#     799 if self._validate:
#     800     if index is NOTSET:
#
# ValueError: Invalid parameter value: ReserveRequirement[4] = 'nan', value type=<class 'float'>.
# 	Value not in parameter domain NonNegativeReals

# %%
def get_total_CO2_emitted(report_dfs):
    # Extracting thermal details
    thermal_detail = report_dfs["thermal_detail"].reset_index()
    thermal_detail_CO2 = pd.merge(thermal_detail, CO2_data, left_on = "Generator", right_on = "GEN UID", how = "inner")
    # Dispatch assumed to be in MWh
    thermal_detail_CO2["CO2_Total"] = thermal_detail_CO2["Dispatch"]*thermal_detail_CO2["CO2 Emissions Lbs/MWh"]
    CO2_total = thermal_detail_CO2["CO2_Total"].sum()
    CO2_total = convert_lbs_to_metric_tons(CO2_total)
    return CO2_total
